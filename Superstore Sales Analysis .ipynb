# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\Vijay\\OneDrive\\Desktop\\Nanda\\several csv files\\train.csv")

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# # Finding duplicated Value

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Postal Code"].isnull().sum()
# Out:
# 11

# %% [markdown]
# Filling the missing values with 0

# %%
df["Postal Code"].fillna(0,inplace = True)

# %%
df["Postal Code"] = df["Postal Code"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9800 non-null   int32
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# # Exploratory Data Analysis¶

# %% [markdown]
# ## Customer Analysis

# %% [markdown]
# ### 1.Segment

# %%
number_of_customer = df["Segment"].value_counts().reset_index()

# %%
number_of_customer = number_of_customer.rename(columns={"Segment": "Total Customer", "index":"Customer Type"})
number_of_customer
# Out:
#   Customer Type  Total Customer
# 0      Consumer            5101
# 1     Corporate            2953
# 2   Home Office            1746

# %%
plt.figure(figsize=(8, 8))  # Set the figure size
plt.pie(number_of_customer['Total Customer'], labels=number_of_customer["Customer Type"], autopct='%1.1f%%')
plt.title("Distribution of Customers")
# Out:
# Text(0.5, 1.0, 'Distribution of Customers')

# %% [markdown]
# From above diagram we can see most of the customer are Consumer.

# %% [markdown]
# ### Customers and Sales

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
sales_by_customers = df.groupby("Segment")["Sales"].sum().reset_index()
sales_by_customers = sales_by_customers.rename(columns = {"Segment":"Customer Type","Sales":"Total Sales"})
sales_by_customers
# Out:
#   Customer Type   Total Sales
# 0      Consumer  1.148061e+06
# 1     Corporate  6.884941e+05
# 2   Home Office  4.249822e+05

# %%
plt.bar(sales_by_customers['Customer Type'], sales_by_customers['Total Sales'])
plt.title("Sales Distribution by Customers")
plt.show()

# %% [markdown]
# From above chart we can see most sales done by Consumer

# %% [markdown]
# ## Customer Loyalty

# %%
customer_order_freq = df.groupby(['Customer ID', 'Customer Name', 'Segment'])['Order ID'].count().reset_index()
customer_order_freq = customer_order_freq.rename(columns={"Order ID":"Total Orders"})

# Identify Repeat Customers 
repeat_customers = customer_order_freq[customer_order_freq['Total Orders'] >= 1]

# Sorted repeat Orders
sorted_repeat_customers = repeat_customers.sort_values(by='Total Orders', ascending=False)

print(sorted_repeat_customers.head(10).reset_index(drop=True))
# Out:
#   Customer ID        Customer Name      Segment  Total Orders
# 0    WB-21850        William Brown     Consumer            35
# 1    PP-18955           Paul Prost  Home Office            34
# 2    MA-17560         Matt Abelman  Home Office            34
# 3    JL-15835             John Lee     Consumer            33
# 4    CK-12205  Chloris Kastensmidt     Consumer            32
# 5    SV-20365          Seth Vernon     Consumer            32
# 6    JD-15895     Jonathan Doherty    Corporate            32
# 7    AP-10915       Arthur Prichep     Consumer            31
# 8    ZC-21910     Zuschuss Carroll     Consumer            31
# 9    EP-13915           Emily Phan     Consumer            31

# %%
# Group Data based on: Customer Name, Customer ID and Sales

customer_sales = df.groupby(['Customer ID', 'Customer Name'])['Sales'].sum().reset_index()

# Sort in Descending order

top_spenders = customer_sales.sort_values(by='Sales', ascending=False).head(10)


print(top_spenders.head(10).reset_index(drop=True))
# Out:
#   Customer ID       Customer Name      Sales
# 0    SM-20320         Sean Miller  25043.050
# 1    TC-20980        Tamara Chand  19052.218
# 2    RB-19360        Raymond Buch  15117.339
# 3    TA-21385        Tom Ashbrook  14595.620
# 4    AB-10105       Adrian Barton  14473.571
# 5    KL-16645        Ken Lonsdale  14175.229
# 6    SC-20095        Sanjit Chand  14142.334
# 7    HL-15040        Hunter Lopez  12873.298
# 8    SE-20110        Sanjit Engle  12209.438
# 9    CC-12370  Christopher Conant  12129.072

# %%
plt.bar(top_spenders['Customer Name'], top_spenders['Sales'])
plt.title("Top Customers ")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# from above barchart we knows they are top 10 customers

# %% [markdown]
# ### Mode of Shipping

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
shipping_mode = df["Ship Mode"].value_counts().reset_index()
shipping_mode = shipping_mode.rename(columns={"index":"Ship Mode","Ship Mode":"Use Frequency"})

# %%
shipping_mode
# Out:
#         Ship Mode  Use Frequency
# 0  Standard Class           5859
# 1    Second Class           1902
# 2     First Class           1501
# 3        Same Day            538

# %%
plt.pie(shipping_mode['Use Frequency'], labels=shipping_mode['Ship Mode'], autopct='%1.1f%%')
plt.title("Popular Shipping Modes")
plt.show()

# %% [markdown]
# From above piechart we knows maximum Shipping in Standard Class

# %% [markdown]
# ## Graphical Analysis

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# Customers by City 

city = df['City'].value_counts().reset_index()
city = city.rename(columns={"index":"City", "City":"Number of Customers"})
city.head()
# Out:
#             City  Number of Customers
# 0  New York City                  891
# 1    Los Angeles                  728
# 2   Philadelphia                  532
# 3  San Francisco                  500
# 4        Seattle                  426

# %%
# Customer by State

state = df["State"].value_counts().reset_index()
state = state.rename(columns={"index":"State","count":"Number of Customers"})
state.head()
# Out:
#           State  State
# 0    California   1946
# 1      New York   1097
# 2         Texas    973
# 3  Pennsylvania    582
# 4    Washington    504

# %%
# Sales by State
state_sales = df.groupby('State')['Sales'].sum().reset_index()

# Sort in Descending order

top_state_sales = state_sales.sort_values(by='Sales', ascending=False)

top10_state_sales = state_sales.sort_values(by='Sales', ascending=False).head(10)

top_state_sales.head(10).reset_index(drop=True)
# Out:
#           State        Sales
# 0    California  446306.4635
# 1      New York  306361.1470
# 2         Texas  168572.5322
# 3    Washington  135206.8500
# 4  Pennsylvania  116276.6500
# 5       Florida   88436.5320
# 6      Illinois   79236.5170
# 7      Michigan   76136.0740
# 8          Ohio   75130.3500
# 9      Virginia   70636.7200

# %%
plt.bar(top10_state_sales['State'], top10_state_sales['Sales'])
plt.title("Top Sales by State")
plt.xticks(rotation=90)
plt.show()

# %%
# Sales by City
city_sales = df.groupby('City')['Sales'].sum().reset_index()

# Sort in Descending order

top_city_sales = city_sales.sort_values(by='Sales', ascending=False)

top10_city_sales = city_sales.sort_values(by='Sales', ascending=False).head(10)


top_city_sales.head(10).reset_index(drop=True)
# Out:
#             City        Sales
# 0  New York City  252462.5470
# 1    Los Angeles  173420.1810
# 2        Seattle  116106.3220
# 3  San Francisco  109041.1200
# 4   Philadelphia  108841.7490
# 5        Houston   63956.1428
# 6        Chicago   47820.1330
# 7      San Diego   47521.0290
# 8   Jacksonville   44713.1830
# 9        Detroit   42446.9440

# %%
plt.bar(top10_city_sales['City'], top10_city_sales['Sales'])
plt.title("Top Sales by City")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Product Category

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
Type_of_Category = df["Category"].unique()
Type_of_Category
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Group Data by categories

category_count = df.groupby('Category')['Sub-Category'].nunique().reset_index()

# Sort Values by Sub-Category
category_count = category_count.sort_values(by='Sub-Category', ascending=False)

category_count.head(5).reset_index(drop=True)
# Out:
#           Category  Sub-Category
# 0  Office Supplies             9
# 1        Furniture             4
# 2       Technology             4

# %%
#sales per each Category

Sales_by_Category = df.groupby("Category")["Sales"].sum().reset_index()

# sort Value by Sales

Sales_by_Category = Sales_by_Category.sort_values(by ="Sales",ascending=False)

Sales_by_Category.head(5).reset_index(drop =True)
# Out:
#           Category        Sales
# 0       Technology  827455.8730
# 1        Furniture  728658.5757
# 2  Office Supplies  705422.3340

# %%
# pie chart
plt.pie(Sales_by_Category['Sales'], labels=Sales_by_Category['Category'], autopct='%1.1f%%')
plt.title("Sales by category")
plt.show()

# %% [markdown]
# From above Piechart we known that, most Sales happen in Technology category(36.6%)

# %%
# Group Data by Sub-categories

sales_by_SubCategory = df.groupby(["Sub-Category","Category"])["Sales"].sum().reset_index()

# sort Value by Sales

sales_by_SubCategory = sales_by_SubCategory.sort_values(by="Sales",ascending=True)

sales_by_SubCategory.head(10).reset_index(drop=True)
# Out:
#   Sub-Category         Category        Sales
# 0    Fasteners  Office Supplies    3001.9600
# 1       Labels  Office Supplies   12347.7260
# 2    Envelopes  Office Supplies   16128.0460
# 3          Art  Office Supplies   26705.4100
# 4     Supplies  Office Supplies   46420.3080
# 5        Paper  Office Supplies   76828.3040
# 6  Furnishings        Furniture   89212.0180
# 7   Appliances  Office Supplies  104618.4030
# 8    Bookcases        Furniture  113813.1987
# 9      Copiers       Technology  146248.0940

# %%
plt.barh(sales_by_SubCategory['Sub-Category'], sales_by_SubCategory['Sales'])
plt.xlabel("Sales")
plt.ylabel("Top Sub-Categories")
plt.show()

# %% [markdown]
# ## Sales

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

yearly_sales = df.groupby(df['Order Date'].dt.year)['Sales'].sum().reset_index()

yearly_sales = yearly_sales.rename(columns={'Order Date':"Year", "Date":"Total Sales"})

yearly_sales
# Out:
#    Year        Sales
# 0  2015  479856.2081
# 1  2016  459436.0054
# 2  2017  600192.5500
# 3  2018  722052.0192

# %%
# Plotting the bar Chart

plt.bar(yearly_sales['Year'], yearly_sales['Sales'])
plt.xlabel("Years")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting the line Chart

plt.plot(yearly_sales['Year'], yearly_sales['Sales'], marker='o')

#Label
plt.xlabel("Years")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# We above Line chart we known, from 2016 to 2018 sales is gradually increasing.

# %% [markdown]
# ## Monthly Sales Trend of the Year

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# Filter Data according to Year
year_sale = df[df['Order Date'].dt.year == 2018]


# Calculate Monthly Sales of Year 2018
monthly_sale = year_sale.resample("M", on='Order Date')['Sales'].sum()

# Rename the columns
monthly_sale = monthly_sale.reset_index()
monthly_sale = monthly_sale.rename(columns={'Order Date': "Month", 'Sales':'Total Monthly Sales'})



print("These are the monthly sales of 2018")
monthly_sale
# Out:
# These are the monthly sales of 2018
#         Month  Total Monthly Sales
# 0  2018-01-31           43476.4740
# 1  2018-02-28           19920.9974
# 2  2018-03-31           58863.4128
# 3  2018-04-30           35541.9101
# 4  2018-05-31           43825.9822
# 5  2018-06-30           48190.7277
# 6  2018-07-31           44825.1040
# 7  2018-08-31           62837.8480
# 8  2018-09-30           86152.8880
# 9  2018-10-31           77448.1312
# 10 2018-11-30          117938.1550
# 11 2018-12-31           83030.3888

# %%
# Plotting the line Chart

plt.plot(monthly_sale['Month'], monthly_sale['Total Monthly Sales'], marker='o')

#Label
plt.xlabel("Months")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# from above line chart we known, most sales happen in the month of 12 year 2018.
